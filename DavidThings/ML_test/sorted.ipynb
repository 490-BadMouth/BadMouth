# %%
import os
import glob
from matplotlib import pyplot as plt
import tensorflow as tf
import tensorflow_io as tfio
import numpy as np
from keras import models
from recorder import record_audio, terminate
from spec import preprocess
import pyaudio
import wave

loaded_model = models.load_model("bad_mouth_1c_16n_0d_newData.model")

# %%
def predict_mic():
    #for wav_file in sorted(glob.glob('C:/Users/David/Documents/ML Training Audios/ML_test/test_negs/*.wav', recursive=False)):
    for wav_file in sorted(glob.glob('C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp/*.wav', recursive=False)):
        
        pos = tf.data.Dataset.list_files(wav_file) 

        # append correct label to data
        data = tf.data.Dataset.zip((pos, tf.data.Dataset.from_tensor_slices(tf.zeros(len(pos)))))

        # apply preprocess to all the files 
        data = data.map(preprocess)

        # process data in batches of 16
        data = data.batch(16)

        # get next batch
        sample, labels = data.as_numpy_iterator().next()

        #print(sample.shape)
        prediction = loaded_model.predict(sample)
        
        #print(prediction.shape)
        
        # iterate through the batch
        for i in np.nditer(prediction): 
            print(wav_file)
            if (i > 0.9):
                print("Bad Word  -- Prob:", i)
            
            else:
                print("Good word -- Prob:", i)
        

        # prediction = [1 if prediction > 0.99 else 0 for prediction in prediction]

    return prediction

# %%
if __name__ == "__main__":
    # while True:
    predict_mic()
    terminate()
# Out:
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 282ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio1.wav
# Bad Word  -- Prob: 0.9332379
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 16ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio10.wav
# Bad Word  -- Prob: 0.9760686
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 18ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio100.wav
# Bad Word  -- Prob: 0.99942774
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 16ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio101.wav
# Bad Word  -- Prob: 0.9999869
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 16ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio102.wav
# Bad Word  -- Prob: 0.94892293
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 15ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio103.wav
# Good word -- Prob: 0.6337039
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 17ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio104.wav
# Good word -- Prob: 0.30422872
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 17ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio105.wav
# Bad Word  -- Prob: 0.9783426
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 18ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio106.wav
# Bad Word  -- Prob: 0.98710454
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 18ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio107.wav
# Bad Word  -- Prob: 0.9874445
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 17ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio108.wav
# Good word -- Prob: 0.5116011
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 17ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio109.wav
# Good word -- Prob: 0.37769675
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 18ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio11.wav
# Good word -- Prob: 0.88688207
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 18ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio110.wav
# Bad Word  -- Prob: 0.9954229
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 18ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio111.wav
# Good word -- Prob: 0.61670446
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 18ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio112.wav
# Bad Word  -- Prob: 0.9580896
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 18ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio113.wav
# Good word -- Prob: 0.83651966
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 17ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio114.wav
# Good word -- Prob: 0.6902211
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 18ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio115.wav
# Good word -- Prob: 0.6767732
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 16ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio116.wav
# Bad Word  -- Prob: 0.99532914
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 17ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio117.wav
# Good word -- Prob: 0.7877791
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 18ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio118.wav
# Good word -- Prob: 0.35736063
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 17ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio119.wav
# Good word -- Prob: 0.7003638
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 16ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio12.wav
# Good word -- Prob: 0.67487013
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 18ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio120.wav
# Bad Word  -- Prob: 0.98907685
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 18ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio121.wav
# Good word -- Prob: 0.485072
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 17ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio122.wav
# Good word -- Prob: 0.11140432
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 18ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio123.wav
# Good word -- Prob: 0.29077077
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 18ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio124.wav
# Good word -- Prob: 0.8501607
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 17ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio125.wav
# Good word -- Prob: 0.556721
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 16ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio126.wav
# Good word -- Prob: 0.5973284
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 17ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio127.wav
# Bad Word  -- Prob: 1.0
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 18ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio128.wav
# Bad Word  -- Prob: 0.9944226
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 16ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio129.wav
# Good word -- Prob: 0.802395
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 17ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio13.wav
# Good word -- Prob: 0.7401898
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 16ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio130.wav
# Bad Word  -- Prob: 0.99999714
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 18ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_audio131.wav
# Good word -- Prob: 0.8149116
# WARNING:tensorflow:Using a while_loop for converting IO>AudioResample cause there is no registered converter for this op.
# 1/1 [==============================] - 0s 16ms/step
# C:/Users/David/Documents/ML Training Audios/ML_test/fuck_comp\fuck_aud